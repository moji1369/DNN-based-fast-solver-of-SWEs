# %%
import numpy as np
import copy
from sklearn.model_selection import train_test_split
import keras
from keras.models import Model, Sequential
from keras import regularizers
from keras import backend as K
import Data_prep as dp
from scipy.io import savemat, loadmat
from keras.losses import mse, binary_crossentropy
from keras.layers import Reshape, Lambda, Input, Dense, Flatten, Conv2D, Conv2DTranspose
from keras.layers import Activation, ZeroPadding2D, BatchNormalization, MaxPooling2D, UpSampling2D
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model
K.set_image_data_format('channels_last')
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#encoder network:

#regularization coefficient:
l_encode=0.001

#act. func. (hidden layers)
act='tanh'

#act. func. (output layers)
act_out='linear'

#input:
bathy_input = Input(shape=(41,501, 1), name = 'bathymetry')

#CNN/pooling layer 1&2:
x = Conv2D(4, (3, 3), strides=1, padding='same',kernel_regularizer = regularizers.l2(l_encode))(bathy_input)
#x = BatchNormalization(axis = 3)(x)
x = Activation(act)(x)
x = Conv2D(4, (3, 3), strides=1, padding='same',kernel_regularizer = regularizers.l2(l_encode))(x)
#x = BatchNormalization(axis = 3)(x)
x = Activation(act)(x)
x = MaxPooling2D((2, 2), padding='same')(x)

#CNN/pooling layer 3&4:
x = Conv2D(8, (3, 3), strides=1, padding='same',kernel_regularizer = regularizers.l2(l_encode))(x)
#x = BatchNormalization(axis = 3)(x)
x = Activation(act)(x)
x = Conv2D(8, (3, 3), strides=1, padding='same',kernel_regularizer = regularizers.l2(l_encode))(x)
#x = BatchNormalization(axis = 3)(x)
x = Activation(act)(x)
x = MaxPooling2D((2, 2), padding='same')(x)

#CNN/pooling layer 5&6:
x = Conv2D(16, (3, 3), strides=1, padding='same',kernel_regularizer = regularizers.l2(l_encode))(x)
#x = BatchNormalization(axis = 3)(x)
x = Activation(act)(x)
x = Conv2D(16, (3, 3), strides=1, padding='same',kernel_regularizer = regularizers.l2(l_encode))(x)
#x = BatchNormalization(axis = 3)(x)
x = Activation(act)(x)
x = MaxPooling2D((2, 2), padding='same')(x)

#flattening:
shape = K.int_shape(x)
x = Flatten()(x)

#fully connected layer 1:
x = Dense(1000,kernel_regularizer = regularizers.l2(l_encode))(x)
#x = BatchNormalization(axis = 1)(x)
x = Activation(act)(x)

#fully connected layer 2:
x = Dense(200,kernel_regularizer = regularizers.l2(l_encode))(x)
#x = BatchNormalization(axis = 1)(x)
x = Activation(act)(x)

#output:
z = Dense(50,activation=act_out,kernel_regularizer = regularizers.l2(l_encode), name = 'latent_encode')(x)

#set encoder model:
encoder = Model(bathy_input, z, name='encoder')
encoder.summary()
# Out:
# Model: "encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bathymetry (InputLayer)      (None, 41, 501, 1)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 41, 501, 4)        40
# _________________________________________________________________
# activation_26 (Activation)   (None, 41, 501, 4)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 41, 501, 4)        148
# _________________________________________________________________
# activation_27 (Activation)   (None, 41, 501, 4)        0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 21, 251, 4)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 21, 251, 8)        296
# _________________________________________________________________
# activation_28 (Activation)   (None, 21, 251, 8)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 21, 251, 8)        584
# _________________________________________________________________
# activation_29 (Activation)   (None, 21, 251, 8)        0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 11, 126, 8)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 11, 126, 16)       1168
# _________________________________________________________________
# activation_30 (Activation)   (None, 11, 126, 16)       0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 11, 126, 16)       2320
# _________________________________________________________________
# activation_31 (Activation)   (None, 11, 126, 16)       0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 6, 63, 16)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 6048)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1000)              6049000
# _________________________________________________________________
# activation_32 (Activation)   (None, 1000)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 200)               200200
# _________________________________________________________________
# activation_33 (Activation)   (None, 200)               0
# _________________________________________________________________
# latent_encode (Dense)        (None, 50)                10050
# =================================================================
# Total params: 6,263,806
# Trainable params: 6,263,806
# Non-trainable params: 0
# _________________________________________________________________

# %%
#decoder network:

#regularization coefficient
l_decode=0.001

#input/BC:
BC_input = Input(shape=(2, ), name = 'BC') #BC
latent_input = Input(shape=(50,), name='latent_decode') #input
x = keras.layers.concatenate([latent_input, BC_input])

#fully connected layer 1:
x = Dense(200, kernel_regularizer = regularizers.l2(l_decode))(x)
#x = BatchNormalization(axis = 1)(x)
x = Activation(act)(x)

#fully connected layer 2:
x = Dense(1000, kernel_regularizer = regularizers.l2(l_decode))(x)
#x = BatchNormalization(axis = 1)(x)
x = Activation(act)(x)

#FC/CNN connection & reshaping:
x = Dense((shape[1]-1)*(shape[2]-1)*shape[3], kernel_regularizer = regularizers.l2(l_decode))(x)
#x = BatchNormalization(axis = 1)(x)
x = Activation(act)(x)
x = Reshape((shape[1]-1, shape[2]-1, shape[3]))(x)

#CNN/upsampling layer 1:
x = Conv2DTranspose(16, (3, 3), padding='same', kernel_regularizer = regularizers.l2(l_decode))(x)
#x = BatchNormalization(axis = 3)(x)
x = Activation(act)(x)
x = Conv2DTranspose(16, (3, 3), padding='same', kernel_regularizer = regularizers.l2(l_decode))(x)
#x = BatchNormalization(axis = 3)(x)
x = Activation(act)(x)
x = UpSampling2D((2, 2))(x)

#CNN/upsampling layer 1:
x = Conv2DTranspose(8, (3, 3), padding='same', kernel_regularizer = regularizers.l2(l_decode))(x)
#x = BatchNormalization(axis = 3)(x)
x = Activation(act)(x)
x = Conv2DTranspose(8, (3, 3), padding='same', kernel_regularizer = regularizers.l2(l_decode))(x)
#x = BatchNormalization(axis = 3)(x)
x = Activation(act)(x)
x = UpSampling2D((2, 2))(x)

#CNN/upsampling layer 2:
x = Conv2DTranspose(4, (3, 3), padding='same', kernel_regularizer = regularizers.l2(l_decode))(x)
#x = BatchNormalization(axis = 3)(x)
x = Activation(act)(x)
x = Conv2DTranspose(4, (3, 3), padding='same', kernel_regularizer = regularizers.l2(l_decode))(x)
#x = BatchNormalization(axis = 3)(x)
x = Activation(act)(x)
x = UpSampling2D((2, 2))(x)

#output:
outputs = Conv2DTranspose(1, (3, 3), activation=act_out, padding='same', name='velocity')(x)

#set decoder model:
decoder = Model([latent_input,BC_input], outputs, name='decoder')
decoder.summary()
# Out:
# Model: "decoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# latent_decode (InputLayer)      (None, 50)           0
# __________________________________________________________________________________________________
# BC (InputLayer)                 (None, 2)            0
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 52)           0           latent_decode[0][0]
#                                                                  BC[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 200)          10600       concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 200)          0           dense_10[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1000)         201000      activation_34[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 1000)         0           dense_11[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 4960)         4964960     activation_35[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 4960)         0           dense_12[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 5, 62, 16)    0           activation_36[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 5, 62, 16)    2320        reshape_2[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 5, 62, 16)    0           conv2d_transpose_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 5, 62, 16)    2320        activation_37[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 5, 62, 16)    0           conv2d_transpose_8[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 10, 124, 16)  0           activation_38[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 10, 124, 8)   1160        up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 10, 124, 8)   0           conv2d_transpose_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 10, 124, 8)   584         activation_39[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 10, 124, 8)   0           conv2d_transpose_10[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 20, 248, 8)   0           activation_40[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 20, 248, 4)   292         up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 20, 248, 4)   0           conv2d_transpose_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_12 (Conv2DTran (None, 20, 248, 4)   148         activation_41[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 20, 248, 4)   0           conv2d_transpose_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 40, 496, 4)   0           activation_42[0][0]
# __________________________________________________________________________________________________
# velocity (Conv2DTranspose)      (None, 40, 496, 1)   37          up_sampling2d_6[0][0]
# ==================================================================================================
# Total params: 5,183,421
# Trainable params: 5,183,421
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#set AE model:
ae_outputs = decoder([encoder(bathy_input),BC_input])
ae = Model([bathy_input,BC_input], ae_outputs, name='ae')

# %%
#AE loss function (can use loss='mse' instead, but the function below allows defining custom loss function):

def ae_loss(y_true, y_pred):
    ae_loss = mse(K.flatten(y_true), K.flatten(y_pred))
    return ae_loss

# %%
#compile AE:

opt = keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, decay=0.001, amsgrad=False)

ae.compile(optimizer=opt, loss=ae_loss)
ae.summary()
# Out:
# Model: "ae"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# bathymetry (InputLayer)         (None, 41, 501, 1)   0
# __________________________________________________________________________________________________
# encoder (Model)                 (None, 50)           6263806     bathymetry[0][0]
# __________________________________________________________________________________________________
# BC (InputLayer)                 (None, 2)            0
# __________________________________________________________________________________________________
# decoder (Model)                 (None, 40, 496, 1)   5183421     encoder[1][0]
#                                                                  BC[0][0]
# ==================================================================================================
# Total params: 11,447,227
# Trainable params: 11,447,227
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#load/read train and validation data

data = loadmat('Sav_BC_func_PCGA_1std_noise10_std4_zmax94_48_12_s0_5_6.mat')

vel0 = data['velocity_prof'] #velocities
z_f0 = data['z_f'] #free surface elevation
Q_b0 = data['Q_b'] #influx
Z0 = data['Z'] #bathymetry

#check data shape:
print(z_f0.shape)
print(Z0.shape)
# Out:
# (1, 4500)
# (20541, 4500)

# %%
#load/read test data

data = loadmat('Sav_BC_func_PCGA_1std_noise10_std4_zmax94_48_12_s0_5_6_test.mat')

vel1 = data['velocity_prof'] #velocities
z_f1 = data['z_f'] #free surface elevation
Q_b1 = data['Q_b'] #influx
Z1 = data['Z'] #bathymetry

#check data shape:
print(z_f1.shape)
print(Z1.shape)
# Out:
# (1, 450)
# (20541, 450)

# %%
#join train/validation and test set

vel = np.concatenate((vel0,vel1),axis=1)
z_f = np.concatenate((z_f0,z_f1),axis=1)
Q_b = np.concatenate((Q_b0,Q_b1),axis=1)
Z = np.concatenate((Z0,Z1),axis=1)
vx, vy, _ = dp.xy_vel_sep(vel) #v_x/v_y separation

#check data shape:
print(vel.shape)
print(z_f.shape)
print(vx.shape)
print(Z.shape)
# Out:
# (41082, 4950)
# (1, 4950)
# (20541, 4950)
# (20541, 4950)

# %%
#put bathymetry in right shape:

Z_dummy = Z.reshape(41,501,-1) 
Z_new = np.zeros((Z_dummy.shape[2],Z_dummy.shape[0],Z_dummy.shape[1])) 
for i in range(Z_dummy.shape[2]):
    Z_new[i,:,:] = Z_dummy[:,:,i]     
del Z_dummy

#check Z_new shape:
print(Z_new.shape)
# Out:
# (4950, 41, 501)

# %%
#put v_x in right shape:

vx_dummy = vx.reshape(41,501,-1)
vx_new = np.zeros((vx_dummy.shape[2],vx_dummy.shape[0],vx_dummy.shape[1]))
for i in range(vx_dummy.shape[2]):
    vx_new[i,:,:] = vx_dummy[:,:,i]
del vx_dummy

#check vx_new shape:
print(vx_new.shape)
# Out:
# (4950, 41, 501)

# %%
#put v_y in right shape (if necessary): 

vy_dummy = vy.reshape(41,501,-1)
vy_new = np.zeros((vy_dummy.shape[2],vy_dummy.shape[0],vy_dummy.shape[1]))
for i in range(vy_dummy.shape[2]):
    vy_new[i,:,:] = vy_dummy[:,:,i]
del vy_dummy

#check vy_new shape:
print(vy_new.shape)
# Out:
# (4950, 41, 501)

# %%
#add channel dimension:

x_train = Z_new.reshape(-1,41,501,1) #input (Z)
y_train = vx_new.reshape(-1,41,501,1) #output (vx; can be replaced with vy or both vx/vy)

#check shapes:
print(x_train.shape)
print(y_train.shape)
# Out:
# (4950, 41, 501, 1)
# (4950, 41, 501, 1)

# %%
#find normalizing parameters:

N=4500 # number of data to be used (train+validation)

x_min = np.mean(x_train[:N,:,:,:], axis=0)
y_min = np.mean(y_train[:N,:,:,:], axis=0)
x_range = np.std(x_train[:N,:,:,:], axis=0)
x_range[x_range==0]=1
y_range = np.std(y_train[:N,:,:,:], axis=0)
y_range[y_range==0]=1

#check shapes:
print(x_min.shape)
print(y_min.shape)
print(x_range.shape)
print(y_range.shape)
# Out:
# (41, 501, 1)
# (41, 501, 1)
# (41, 501, 1)
# (41, 501, 1)

# %%
#normalize input/outputs:

x_train_norm = (x_train-x_min)/x_range 
y_train_norm = (y_train-y_min)/y_range 

#check shapes:
print(x_train_norm.shape)
print(y_train_norm.shape)

#check min/max:
print(np.min(x_train_norm))
print(np.min(y_train_norm))
print(np.max(x_train_norm))
print(np.max(y_train_norm))
# Out:
# (4950, 41, 501, 1)
# (4950, 41, 501, 1)
# -4.711301465906763
# -10.378835518374794
# 3.3733705633020246
# 10.965771092609335

# %%
#normalize BC (ensure it's between 0 and 1):

BC = np.zeros((2, z_f.shape[1]))
BC[0,:] = z_f/120
BC[1,:] = Q_b/30000

#check shapes and maxes:
print(BC.shape)
print(max(BC[0,:]))
print(max(BC[1,:]))
# Out:
# (2, 4950)
# 0.9531882083041187
# 0.9988410701086574

# %%
# data preparation:

#generate a seed number for reproducibility:
seed_num=np.random.randint(0,1e5) 
#seed_num=0 #use for reproducing a previously known seed #
print(seed_num)

#generate seed:
np.random.seed(seed_num)

M=0 #where the first index of data is
P=450 #size of test set
H=10 #number of BCs for each profile

#shuffle based on the seed:
indx=np.array(np.arange(0+M,x_train_norm[0:,:,:,:].shape[0]-P,H),dtype=int) #original indices (ascending) 
indx_new=copy.deepcopy(indx) #new (to be shuffled) indices
np.random.shuffle(indx_new) #shuffled idices

#create shuffled input/outputs:
x_train_norm_shfl=copy.deepcopy(x_train_norm[0:,:,:,:])
y_train_norm_shfl=copy.deepcopy(y_train_norm[0:,:,:,:])
BC_shfl=copy.deepcopy(BC[:,0:])
for i in range(indx_new.shape[0]):
    x_train_norm_shfl[i*H+M:i*H+H+M,:,:,:]=x_train_norm[indx_new[i]:indx_new[i]+H,:,:,:]
    y_train_norm_shfl[i*H+M:i*H+H+M,:,:,:]=y_train_norm[indx_new[i]:indx_new[i]+H,:,:,:]
    BC_shfl[:,i*H+M:i*H+H+M]=BC[:,indx_new[i]:indx_new[i]+H]
# Out:
# 84015

# %%
#training:

val_split=0.1 #validation split (fraction of train/validation set to be used for validation)

#ae.load_weights('ae_f_Sav_BC_func_m4500_22_44_B_1000_200_50_l0_001tantanlr0_001B.h5') #to load saved weights, if necessary
ae.fit(x={'bathymetry':x_train_norm_shfl[:-P,:,:,:], 'BC':BC_shfl[:,:-P].T},y=y_train_norm_shfl[:-P,:40,:496,:],
       epochs=100,batch_size=32,shuffle=False,validation_split=val_split)
ae.save_weights('ae_f_Sav_BC_func_m4500_22_44_B_1000_200_50_l0_001tantanlr0_001B.h5') #to save optimized weights
# Out:
# Train on 4050 samples, validate on 450 samples
# Epoch 1/1
# 4050/4050 [==============================] - 56s 14ms/step - loss: 1.3685 - val_loss: 0.7049

# %%
#calculate AE predictions (normalized):

z_pred= encoder.predict(x_train_norm_shfl) #encoder output
y_decoded_pred = decoder.predict([z_pred,BC_shfl.T]) #decoder output

#check shape:
print(y_decoded_pred.shape)
# Out:
# (4950, 40, 496, 1)

# %%
#calculate AE predictions:

n=496
y_pred=y_decoded_pred*y_range[:40,:n,:]+y_min[:40,:n,:] #predicted output

#check shape:
print(y_pred.shape)
# Out:
# (4950, 40, 496, 1)

# %%
#rmse of train/test/validation:

y_true=y_train_norm_shfl[:,:40,:n]*y_range[:40,:n,:]+y_min[:40,:n,:]
print('train err [ft/s]:',np.sqrt(np.mean((y_pred[:int(N-val_split*N),:,:]-y_true[:int(N-val_split*N),:40,:n])**2)))
print('test err [ft/s]:',np.sqrt(np.mean((y_pred[int(N-val_split*N):N,:,:]-y_true[int(N-val_split*N):N,:40,:n])**2)))
print('validation err [ft/s]:',np.sqrt(np.mean((y_pred[N:,:,:]-y_true[N:,:40,:n])**2)))
# Out:
# train err [ft/s]: 0.27841267460268265
# test err [ft/s]: 0.2989945778914711
# validation err [ft/s]: 0.281696358670702

# %%
#prepare the data for plotting

x_plt=np.zeros((N+P,41, 501))
x_plt[:,:40,:500]=y_pred.squeeze()
x_plt[:, 40,:]=x_plt[:, 39,:]
x_plt[:, :,500]=x_plt[:, :,499]
y_plt=np.zeros((N+P,41, 501))
y_plt[:,:40,:500]=y_true.squeeze()
y_plt[:, 40,:]=y_plt[:, 39,:]
y_plt[:, :,500]=y_plt[:, :,499]

# %%
#plot some results:

#index (k<int(N-val_split*N) is a train data, int(N-val_split*N)<k<N is a test data, k>N is a validation data)
k=4700

dp.plt_im_tri(depth=y_plt[k, :,:].ravel(), fig_title= 'reference', fig_name='ref_global.png',vmin_=-0.5, vmax_=0.6)
dp.plt_im_tri(depth=(x_plt[k, :,:]).ravel(), fig_title= 'SE prediction', fig_name='SE_global.png',vmin_=-0.5, vmax_=0.6)
